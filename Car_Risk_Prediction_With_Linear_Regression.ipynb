# %% [markdown]
# <a href="https://colab.research.google.com/github/Omayer-Ahmed/Machine-Learning/blob/main/Car_Risk_Prediction_With_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-da09c761-7180-458c-86e7-f5b9fb8d3396" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da09c761-7180-458c-86e7-f5b9fb8d3396">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df_csv=pd.read_csv("Car_Risk.csv")
df_csv
# Out:
#    Speed  Car_age  Experience  Risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         NaN    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
df_csv[["Experience"]].isnull().sum()
# Out:
# Experience    1
# dtype: int64

# %%
df_csv[["Experience"]]
# Out:
#    Experience
# 0         5.0
# 1        13.0
# 2         4.0
# 3         NaN
# 4         3.0
# 5         8.0

# %%
#set the  value in null position  using mean value
#df_csv.Experience.mean()

# %%
nan = df_csv.Experience.median()
nan
# Out:
# 5.0

# %%
df_csv.Experience=df_csv.Experience.fillna(nan)

# %%
df_csv.Experience
# Out:
# 0     5.0
# 1    13.0
# 2     4.0
# 3     5.0
# 4     3.0
# 5     8.0
# Name: Experience, dtype: float64

# %%
df_csv
# Out:
#    Speed  Car_age  Experience  Risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         5.0    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %%
#create object
reg=LinearRegression()

# %%
reg.fit(df_csv[["Speed","Car_age","Experience"]],df_csv.Risk)
# Out:
# LinearRegression()

# %%
reg.predict([[160,10,5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([71.37146872])

# %%
reg.coef_
# Out:
# array([ 0.33059217,  1.61053246, -6.20772074])

# %%
c = reg.intercept_

# %%
risk=0.33059217*160+1.61053246*10+(-6.20772074*5)+c
risk
# Out:
# 71.37146901043589
