# %% [markdown]
# <a href="https://colab.research.google.com/github/Omayer-Ahmed/Machine-Learning/blob/main/Salary_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-33da09db-5cd8-4d71-a2e4-9d6c2b680675" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33da09db-5cd8-4d71-a2e4-9d6c2b680675">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df_csv=pd.read_csv("Salary Data.csv")

# %%
df_csv.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df_csv.isnull().value_counts()
# Out:
# Experience Years  Salary
# False             False     40
# dtype: int64

# %%
df_csv.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df_csv["Experience Years"],df_csv["Salary"])
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("Salary Data")
# Out:
# Text(0.5, 1.0, 'Salary Data')

# %%
x=df_csv[["Experience Years"]]
x.head()
# Out:
#    Experience Years
# 0               1.1
# 1               1.2
# 2               1.3
# 3               1.5
# 4               2.0

# %%
y=df_csv[["Salary"]]
y.tail()
# Out:
#     Salary
# 35  105582
# 36  116969
# 37  112635
# 38  122391
# 39  121872

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
x.mean()
# Out:
# Experience Years    5.1525
# dtype: float64

# %%
y.mean()
# Out:
# Salary    74743.625
# dtype: float64

# %%
plt.scatter(x.mean(),y.mean(),color="r")
plt.scatter(df_csv["Experience Years"],df_csv["Salary"])
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("Salary Data")
# Out:
# Text(0.5, 1.0, 'Salary Data')

# %%
#train the model using fit() function
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
df_csv["Predict_y"]=reg.predict(x)

# %%
df_csv.head()
# Out:
#    Experience Years  Salary     Predict_y
# 0               1.1   39343  36149.031319
# 1               1.2   42774  37101.396369
# 2               1.3   46205  38053.761420
# 3               1.5   37731  39958.491522
# 4               2.0   43525  44720.316775

# %%
plt.plot(x,df_csv["Predict_y"],color="g")
plt.scatter(x.mean(),y.mean(),color="r")
plt.scatter(df_csv["Experience Years"],df_csv["Salary"])
plt.scatter(df_csv["Experience Years"],df_csv["Predict_y"])
plt.xlabel("Experience Years")
plt.ylabel("Salary")
plt.title("Salary Data")
# Out:
# Text(0.5, 1.0, 'Salary Data')

# %% [markdown]
# #use of cost and  lost function

# %%
#calculate lost or error calculate
df_csv["lost"]=df_csv["Salary"]-df_csv["Predict_y"]
df_csv.head()
# Out:
#    Experience Years  Salary     Predict_y         lost
# 0               1.1   39343  36149.031319  3193.968681
# 1               1.2   42774  37101.396369  5672.603631
# 2               1.3   46205  38053.761420  8151.238580
# 3               1.5   37731  39958.491522 -2227.491522
# 4               2.0   43525  44720.316775 -1195.316775

# %%
# mean square error calculate
from sklearn.metrics import mean_squared_error

# %%
#MSE calculate
mean_squared_error(df_csv["Salary"],df_csv["Predict_y"])
# Out:
# 28960383.65377621

# %%
#MAE calculate
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(df_excel["Ending (USD)"],df_excel["Predict_y"])

# %% [markdown]
# #calculate the performance / accuracy using score() fucntion

# %%
reg.score(x,y)
# Out:
# 0.9558814451799361

# %% [markdown]
# calculate the performance / accuracy using R squared value

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(df_csv["Salary"],reg.predict(x))
score
# Out:
# 0.9558814451799361
